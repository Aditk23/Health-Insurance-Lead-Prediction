# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()

# Hypothesis
# 1. People with Owned accomodation should have more intrest in insurance as compared to people with rented accomodation
# 2. Older people should be intrested in buying health insurance 
# 3.
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# ...

# %%
train.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator           11691
# Holding_Policy_Duration    20251
# Holding_Policy_Type        20251
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                       0
# dtype: int64

# %%
train.shape
# Out:
# (50882, 14)

# %%
test.isnull().sum()
# Out:
# ID                            0
# City_Code                     0
# Region_Code                   0
# Accomodation_Type             0
# Reco_Insurance_Type           0
# Upper_Age                     0
# Lower_Age                     0
# Is_Spouse                     0
# Health Indicator           5027
# Holding_Policy_Duration    8603
# Holding_Policy_Type        8603
# Reco_Policy_Cat               0
# Reco_Policy_Premium           0
# dtype: int64

# %%
test.shape
# Out:
# (21805, 13)

# %%
train.describe(include='all')
# Out:
#                   ID City_Code   Region_Code Accomodation_Type  \
# count   50882.000000     50882  50882.000000             50882
# unique           NaN        36           NaN                 2
# top              NaN        C1           NaN             Owned
# freq             NaN      8973           NaN             27951
# mean    25441.500000       NaN   1732.788707               NaN
# std     14688.512535       NaN   1424.081652               NaN
# min         1.000000       NaN      1.000000               NaN
# 25%     12721.250000       NaN    523.000000               NaN
# 50%     25441.500000       NaN   1391.000000               NaN
# 75%     38161.750000       NaN   2667.000000               NaN
# max     50882.000000       NaN   6194.000000               NaN
#
#        Reco_Insurance_Type     Upper_Age     Lower_Age Is_Spouse  \
# count                50882  50882.000000  50882.000000     50882
# unique                   2           NaN           NaN         2
# ...

# %%
train.Response.value_counts()
# Out:
# 0    38673
# 1    12209
# Name: Response, dtype: int64

# %%
train.Region_Code.unique().shape
# Out:
# (5316,)

# %%
loc = train['City_Code'].value_counts()
chart = sns.barplot(x=loc.index,y=loc)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
plt.show()

# %%
pd.pivot_table(train,index=['Response'],columns=['City_Code'],values=['ID'],aggfunc='count',fill_value=0)
# Out:
#              ID                                                ...           \
# City_Code    C1   C10  C11  C12  C13  C14  C15  C16  C17  C18  ...  C33 C34
# Response                                                       ...
# 0          6765  1247  868  670  750  570  933  866  894  607  ...  215  94
# 1          2208   364  279  198  255  176  253  269  265  190  ...   71  36
#
#
# City_Code C35 C36    C4    C5    C6    C7    C8    C9
# Response
# 0          40  31  2782  1050  1490  1426  1369  1675
# 1          16   5   889   314   460   484   437   510
#
# [2 rows x 36 columns]

# %%
train[train['Response']==1].City_Code.value_counts()
# Out:
# C1     2208
# C2     1893
# C3     1161
# C4      889
# C9      510
# C7      484
# C6      460
# C8      437
# C10     364
# C5      314
# C11     279
# C16     269
# C17     265
# C13     255
# C15     253
# C20     212
# C19     208
# C12     198
# C18     190
# C14     176
# C23     156
# C21     155
# C24     130
# C22     119
# C26     108
# C29      91
# C25      88
# C27      76
# C33      71
# C28      67
# C32      46
# C34      36
# C30      18
# C35      16
# C36       5
# C31       2
# Name: City_Code, dtype: int64

# %%
loc=pd.pivot_table(train,index=['City_Code'],columns=['Response'],values=['ID'],aggfunc='count')[:10]
loc.div(loc.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Response 0", "Response 1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
loc=pd.pivot_table(train,index=['City_Code'],columns=['Response'],values=['ID'],aggfunc='count')[11:20]
loc.div(loc.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Response 0", "Response 1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
loc=pd.pivot_table(train,index=['City_Code'],columns=['Response'],values=['ID'],aggfunc='count')[21:]
loc.div(loc.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Response 0", "Response 1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# ...

# %%
train['Region_Code'].unique().shape
# Out:
# (5316,)

# %%
sns.countplot( x='Response', data=train, hue="Accomodation_Type", palette="Set1");

# %%
acc=pd.pivot_table(train,index=['Accomodation_Type'],columns=['Response'],values=['ID'],aggfunc='count')
acc.div(acc.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Response 0", "Response 1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# ...

# %%
train['Age'] = (train['Upper_Age'] + train['Lower_Age'])//2

# %%
train.Age.min()
# Out:
# 17

# %%
train.Age.max()
# Out:
# 75

# %%
bins = [17,31,55,75]
grp = ['Young','Middle','Old']
train['Age_Type'] = pd.cut(train['Age'],bins,grp)

# %%
train.Age_Type.value_counts()
# Out:
# (31, 55]    19734
# (17, 31]    16566
# (55, 75]    14581
# Name: Age_Type, dtype: int64

# %%
age=pd.pivot_table(train,index=['Age_Type'],columns=['Response'],values=['ID'],aggfunc='count')
age.div(age.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Response 0", "Response 1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
d1 = train.loc[(train['Reco_Insurance_Type']=='Joint')]

# %%
sp=pd.pivot_table(train,index=['Is_Spouse'],columns=['Response'],values=['ID'],aggfunc='count')
sp.div(sp.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Response 0", "Response 1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  Age  \
# ...

# %%
train['Health Indicator'].value_counts()
# Out:
# X1    13010
# X2    10332
# X3     6762
# X4     5743
# X5     1727
# X6     1280
# X7      196
# X8       78
# X9       63
# Name: Health Indicator, dtype: int64

# %%
health=pd.pivot_table(train,index=['Health Indicator'],columns=['Response'],values=['ID'],aggfunc='count')
health.div(health.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Response 0", "Response 1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
health1=pd.pivot_table(train,index=['Health Indicator'],columns=['Age_Type'],values=['ID'],aggfunc='count')
health1.div(health1.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Young", "Middle","Old"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# People belonging to middle and old age are more likely to have Health Indicator X7 and are more likely to buy
# health insurance

# %%
train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  Age  \
# ...

# %%
train['Holding_Policy_Duration'].value_counts()
# Out:
# 1.0     4499
# 14+     4335
# 2.0     4260
# 3.0     3586
# 4.0     2771
# 5.0     2362
# 6.0     1894
# 7.0     1645
# 8.0     1316
# 9.0     1114
# 10.0     813
# 11.0     546
# 12.0     513
# 13.0     511
# 14.0     466
# Name: Holding_Policy_Duration, dtype: int64

# %%
#train['Holding_Policy_Duration'] = train['Holding_Policy_Duration'].replace({'14+':15})
#train['Holding_Policy_Duration'].value_counts()
# Out:
# 1.0     4499
# 15      4335
# 2.0     4260
# 3.0     3586
# 4.0     2771
# 5.0     2362
# 6.0     1894
# 7.0     1645
# 8.0     1316
# 9.0     1114
# 10.0     813
# 11.0     546
# 12.0     513
# 13.0     511
# 14.0     466
# Name: Holding_Policy_Duration, dtype: int64

# %%
#train['Holding_Policy_Duration'] = train['Holding_Policy_Duration'].replace({np.NaN:0})

#train['Holding_Policy_Duration'] = train['Holding_Policy_Duration'].astype('float32').astype('int32')

# %%
#test['Holding_Policy_Duration'] = test['Holding_Policy_Duration'].replace({np.NaN:0})
#test['Holding_Policy_Duration'] = test['Holding_Policy_Duration'].replace({'14+':15})
#test['Holding_Policy_Duration'] = test['Holding_Policy_Duration'].astype('float32').astype('int32')

# %%
train['Holding_Policy_Type'].value_counts()
# Out:
# 3.0    13279
# 1.0     8173
# 2.0     5005
# 4.0     4174
# Name: Holding_Policy_Type, dtype: int64

# %%
dur=pd.pivot_table(train,index=['Holding_Policy_Duration'],columns=['Holding_Policy_Type'],values=['ID'],aggfunc='count')
dur.div(dur.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["1", "2","3","4"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
#bins = [1,5,11,15]
#grp = ['Low','Medium','High']
#train['Holding_Policy_Duration_Type'] = pd.cut(train['Holding_Policy_Duration'],bins,grp)

# %%
#dur=pd.pivot_table(train,index=['Holding_Policy_Type'],columns=['Holding_Policy_Duration_Type'],values=['ID'],aggfunc='count')
#dur.div(dur.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
#plt.legend(["Low", "Medium","High"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
#plt.show()

# %%
train['train_test'] = 0
test['train_test'] = 1
test['Response'] = np.NaN
all_data = pd.concat([train,test])

# %%
all_data.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response   Age  \
# ...

# %%
all_data = all_data.drop(['Age','Age_Type'],1)

# %%
all_data.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator           16718
# Holding_Policy_Duration    28854
# Holding_Policy_Type        28854
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                   21805
# train_test                     0
# dtype: int64

# %%
#all_data.loc[(all_data['Holding_Policy_Duration']==1) & (all_data['Holding_Policy_Type']==np.NaN),'Holding_Policy_Type']=1
#all_data.loc[(all_data['Holding_Policy_Type']==1) & (all_data['Holding_Policy_Duration']==0),'Holding_Policy_Duration']=1

# %%
#all_data.isnull().sum()

# %%
#all_data.Holding_Policy_Duration.value_counts()

# %%
all_data.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
d=all_data.loc[ (pd.isnull(all_data['Holding_Policy_Duration'])) & (pd.isnull(all_data['Holding_Policy_Type']))]

# %%
d
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 1          2        C5         1117             Owned               Joint
# 6          7        C3          679             Owned          Individual
# 10        11       C28          600             Owned          Individual
# 13        14        C5          900            Rented          Individual
# 15        16        C3         1484            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 21790  72673        C1          458             Owned          Individual
# 21791  72674        C6         1067            Rented          Individual
# 21793  72676        C7          685             Owned          Individual
# 21798  72681        C1          340             Owned          Individual
# 21802  72685       C12         2470             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
all_data.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  Age  \
# ...

# %%
train.City_Code.value_counts()
# Out:
# C1     8973
# C2     7747
# C3     4889
# C4     3671
# C9     2185
# C6     1950
# C7     1910
# C8     1806
# C10    1611
# C5     1364
# C15    1186
# C17    1159
# C11    1147
# C16    1135
# C13    1005
# C20     926
# C19     899
# C12     868
# C18     797
# C14     746
# C21     679
# C23     587
# C24     553
# C22     516
# C26     499
# C29     387
# C25     366
# C27     295
# C33     286
# C28     285
# C32     160
# C34     130
# C30      58
# C35      56
# C36      36
# C31      15
# Name: City_Code, dtype: int64

# %%
train = train.drop(['Upper_Age','Lower_Age'],1)

# %%
all_data.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# ...

# %%
all_data['Holding_Policy_Duration'] = all_data['Holding_Policy_Duration'].replace({np.NaN:0})
all_data['Holding_Policy_Duration'] = all_data['Holding_Policy_Duration'].replace({'14+':15})
all_data['Holding_Policy_Duration'] = all_data['Holding_Policy_Duration'].astype('float32').astype('int32')

# %%
all_data.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator           16718
# Holding_Policy_Duration        0
# Holding_Policy_Type        28854
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                   21805
# train_test                     0
# dtype: int64

# %%
all_data['Holding_Policy_Type'] = all_data['Holding_Policy_Type'].replace({np.NaN:0})
all_data['Holding_Policy_Type'] = all_data['Holding_Policy_Type'].astype('int32')

# %%
all_data.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator           16718
# Holding_Policy_Duration        0
# Holding_Policy_Type            0
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                   21805
# train_test                     0
# dtype: int64

# %%
train['Health Indicator'].value_counts()
# Out:
# X1    13010
# X2    10332
# X3     6762
# X4     5743
# X5     1727
# X6     1280
# X7      196
# X8       78
# X9       63
# Name: Health Indicator, dtype: int64

# %%
train.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type Is_Spouse  \
# 0   1        C3         3213            Rented          Individual        No
# 1   2        C5         1117             Owned               Joint        No
# 2   3        C5         3732             Owned          Individual        No
# 3   4       C24         4378             Owned               Joint        No
# 4   5        C8         2190            Rented          Individual        No
#
#   Health Indicator Holding_Policy_Duration  Holding_Policy_Type  \
# 0               X1                     14+                  3.0
# 1               X2                     NaN                  NaN
# 2              NaN                     1.0                  1.0
# 3               X1                     14+                  3.0
# 4               X2                     3.0                  1.0
#
#    Reco_Policy_Cat  Reco_Policy_Premium  Response  Age  Age_Type  train_test
# ...

# %%
age=pd.pivot_table(train,index=['Health Indicator'],columns=['Accomodation_Type'],values=['ID'],aggfunc='count')
age.div(age.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Owned", "Rented"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
d = all_data.loc[all_data['Health Indicator']=='X7']
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 382      383       C33         2063             Owned          Individual
# 455      456       C11          480             Owned          Individual
# 904      905        C2         3468            Rented          Individual
# 1345    1346        C1         2942            Rented          Individual
# 1505    1506        C8         3848             Owned               Joint
# ...      ...       ...          ...               ...                 ...
# 20569  71452        C1         2769             Owned          Individual
# 20654  71537       C12         2470             Owned               Joint
# 20690  71573        C1         2412             Owned               Joint
# 21132  72015        C9          401            Rented          Individual
# 21555  72438        C1          590             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
d['Age'] = (d['Upper_Age'] + d['Lower_Age'])//2

# %%
bins = [17,31,55,75]
grp = ['Young','Middle','Old']
d['Age_Type'] = pd.cut(d['Age'],bins,grp)

# %%
d.Age.mean()
# Out:
# 49.39041095890411

# %%
sns.countplot(d['Age_Type'])
# Out:
# <AxesSubplot:xlabel='Age_Type', ylabel='count'>

# %%
missing = all_data.loc[pd.isnull(all_data['Health Indicator'])]
missing
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 2          3        C5         3732             Owned          Individual
# 6          7        C3          679             Owned          Individual
# 9         10        C1          530             Owned               Joint
# 12        13        C7         3453             Owned          Individual
# 19        20       C20          973             Owned          Individual
# ...      ...       ...          ...               ...                 ...
# 21771  72654        C3          409             Owned               Joint
# 21772  72655        C1           24             Owned          Individual
# 21776  72659        C1         1848             Owned          Individual
# 21783  72666       C24         3515             Owned          Individual
# 21784  72667       C29          112            Rented               Joint
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
missing['Age'] = (missing['Upper_Age'] + missing['Lower_Age'])//2

bins = [17,31,55,75]
grp = ['Young','Middle','Old']
missing['Age_Type'] = pd.cut(missing['Age'],bins,grp)

# %%
sns.countplot(missing['Age_Type'])
# Out:
# <AxesSubplot:xlabel='Age_Type', ylabel='count'>

# %%
indi = all_data.loc[all_data['Reco_Insurance_Type'] == 'Individual']
indi
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 2          3        C5         3732             Owned          Individual
# 4          5        C8         2190            Rented          Individual
# 5          6        C9         1785            Rented          Individual
# 6          7        C3          679             Owned          Individual
# ...      ...       ...          ...               ...                 ...
# 21800  72683        C3         1044             Owned          Individual
# 21801  72684        C4          266             Owned          Individual
# 21802  72685       C12         2470             Owned          Individual
# 21803  72686       C10         1676            Rented          Individual
# 21804  72687        C2         3617             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
sns.countplot(indi['Health Indicator'],order=['X1','X2','X3','X4','X5','X6','X7','X8','X9'])
# Out:
# <AxesSubplot:xlabel='Health Indicator', ylabel='count'>

# %%
join = all_data.loc[all_data['Reco_Insurance_Type'] == 'Joint']
sns.countplot(join['Health Indicator'],order=['X1','X2','X3','X4','X5','X6','X7','X8','X9'])
# Out:
# <AxesSubplot:xlabel='Health Indicator', ylabel='count'>

# %%
d1 = all_data.loc[all_data['Health Indicator']=='X9']

# %%
d1
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 1918    1919       C17         4355             Owned          Individual
# 2393    2394       C17         1296            Rented          Individual
# 3618    3619       C16         1683            Rented          Individual
# 4884    4885       C29          166            Rented          Individual
# 6961    6962        C7         2127             Owned               Joint
# ...      ...       ...          ...               ...                 ...
# 18466  69349       C24         5052             Owned               Joint
# 18677  69560        C7         2127             Owned               Joint
# 18780  69663        C7          625             Owned          Individual
# 19917  70800       C16         1026             Owned               Joint
# 20984  71867       C33         4255             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
sns.countplot(d1['Reco_Insurance_Type'])
# Out:
# <AxesSubplot:xlabel='Reco_Insurance_Type', ylabel='count'>

# %%
d1['Reco_Insurance_Type'].value_counts()
# Out:
# Individual    66
# Joint         25
# Name: Reco_Insurance_Type, dtype: int64

# %%
#all_data.loc[(pd.isnull(all_data['Health Indicator'])) & (all_data['Reco_Insurance_Type'] == 'Individual'), 'Health Indicator'] = 'X7'

# %%
#all_data.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator            3356
# Holding_Policy_Duration        0
# Holding_Policy_Type            0
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                   21805
# train_test                     0
# dtype: int64

# %%
d2 = all_data.loc[all_data['Health Indicator']=='X8']
d2
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 360      361        C7         5777             Owned               Joint
# 566      567        C7         1080             Owned               Joint
# 2283    2284        C2         4524             Owned               Joint
# 2480    2481        C8         4236             Owned          Individual
# 3041    3042        C4         3805             Owned          Individual
# ...      ...       ...          ...               ...                 ...
# 17623  68506       C14         2525            Rented          Individual
# 17821  68704       C16          395            Rented          Individual
# 18074  68957       C14         2201            Rented          Individual
# 21554  72437        C8         1756             Owned          Individual
# 21613  72496       C19         1832            Rented               Joint
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
all_data['Health Indicator'].fillna(method='ffill',inplace=True)

# %%
all_data.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator               0
# Holding_Policy_Duration        0
# Holding_Policy_Type            0
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                   21805
# train_test                     0
# dtype: int64

# %%
all_data
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 21800  72683        C3         1044             Owned          Individual
# 21801  72684        C4          266             Owned          Individual
# 21802  72685       C12         2470             Owned          Individual
# 21803  72686       C10         1676            Rented          Individual
# 21804  72687        C2         3617             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
all_data['Age'] = (all_data['Upper_Age'] + all_data['Lower_Age'])//2

# %%
sns.distplot(all_data['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
all_data['Age_Type'] = np.NaN
all_data.loc[(all_data['Age']>16)&(all_data['Age']<31),'Age_Type'] = 'Young'

all_data.loc[(all_data['Age']>=31)&(all_data['Age']<55),'Age_Type'] = 'MiddleAge'

all_data.loc[(all_data['Age']>=55)&(all_data['Age']<76),'Age_Type'] = 'Old'

# %%
all_data
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 21800  72683        C3         1044             Owned          Individual
# 21801  72684        C4          266             Owned          Individual
# 21802  72685       C12         2470             Owned          Individual
# 21803  72686       C10         1676            Rented          Individual
# 21804  72687        C2         3617             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
all_data.Holding_Policy_Duration.value_counts()
# Out:
# 0     28854
# 1      6390
# 15     6227
# 2      6032
# 3      5192
# 4      3976
# 5      3354
# 6      2797
# 7      2309
# 8      1885
# 9      1607
# 10     1146
# 11      800
# 13      732
# 12      709
# 14      677
# Name: Holding_Policy_Duration, dtype: int64

# %%
t = all_data.loc[all_data['train_test']==0]
t
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 50877  50878        C4          845            Rented          Individual
# 50878  50879        C5         4188            Rented          Individual
# 50879  50880        C1          442            Rented          Individual
# 50880  50881        C1            4             Owned               Joint
# 50881  50882        C3         3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
res=pd.pivot_table(all_data,index=['Holding_Policy_Duration'],columns=['Response'],values=['ID'],aggfunc='count')
res.div(res.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["0", "1"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
t['Holding_Policy_Duration_Type'] = np.NaN
t.loc[(t['Holding_Policy_Duration']>=0)&(t['Holding_Policy_Duration']<5),'Holding_Policy_Duration_Type'] = 'Low'

t.loc[(t['Holding_Policy_Duration']>=5)&(t['Holding_Policy_Duration']<11),'Holding_Policy_Duration_Type'] = 'Medium'

t.loc[(t['Holding_Policy_Duration']>=11)&(t['Holding_Policy_Duration']<16),'Holding_Policy_Duration_Type'] = 'High'

# %%
res=pd.pivot_table(t,index=['Holding_Policy_Duration_Type'],columns=['Response'],values=['ID'],aggfunc='count')
res.div(res.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,figsize=(4,4))
plt.legend(["Low", "Medium","High"],bbox_to_anchor =(1.00, 1.15), ncol = 2) 
plt.show()

# %%
sns.distplot(all_data['Holding_Policy_Duration'])
# Out:
# <AxesSubplot:xlabel='Holding_Policy_Duration', ylabel='Density'>

# %%
sns.distplot(all_data['Reco_Policy_Premium'])
# Out:
# <AxesSubplot:xlabel='Reco_Policy_Premium', ylabel='Density'>

# %%
all_data
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 21800  72683        C3         1044             Owned          Individual
# 21801  72684        C4          266             Owned          Individual
# 21802  72685       C12         2470             Owned          Individual
# 21803  72686       C10         1676            Rented          Individual
# 21804  72687        C2         3617             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
all_data = all_data.drop(['ID','Region_Code','Upper_Age','Lower_Age','Age'],1)

# %%
train_cleaned = all_data.loc[all_data['train_test']==0]
test_cleaned = all_data.loc[all_data['train_test']==1]

# %%
train_cleaned = train_cleaned.drop(['train_test'],1)
test_cleaned = test_cleaned.drop(['train_test','Response'],1)

# %%
train_cleaned
# Out:
#       City_Code Accomodation_Type Reco_Insurance_Type Is_Spouse  \
# 0            C3            Rented          Individual        No
# 1            C5             Owned               Joint        No
# 2            C5             Owned          Individual        No
# 3           C24             Owned               Joint        No
# 4            C8            Rented          Individual        No
# ...         ...               ...                 ...       ...
# 50877        C4            Rented          Individual        No
# 50878        C5            Rented          Individual        No
# 50879        C1            Rented          Individual        No
# 50880        C1             Owned               Joint        No
# 50881        C3            Rented          Individual        No
#
#       Health Indicator  Holding_Policy_Duration  Holding_Policy_Type  \
# 0                   X1                       15                    3
# ...

# %%
test_cleaned
# Out:
#       City_Code Accomodation_Type Reco_Insurance_Type Is_Spouse  \
# 0            C1             Owned          Individual        No
# 1            C4             Owned               Joint       Yes
# 2            C1            Rented          Individual        No
# 3            C3            Rented          Individual        No
# 4            C1             Owned          Individual        No
# ...         ...               ...                 ...       ...
# 21800        C3             Owned          Individual        No
# 21801        C4             Owned          Individual        No
# 21802       C12             Owned          Individual        No
# 21803       C10            Rented          Individual        No
# 21804        C2             Owned          Individual        No
#
#       Health Indicator  Holding_Policy_Duration  Holding_Policy_Type  \
# 0                   X7                        6                    3
# ...

# %%
X = train_cleaned.drop(['Response'],1)
y = train_cleaned.Response

# %%
X = pd.get_dummies(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred = model.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.757959279930823

# %%
test_dummy = pd.get_dummies(test_cleaned)
test_pred = model.predict(test_dummy)

# %%
test_pred = test_pred.astype('int32')

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_logistic.csv',index=False)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()
                                       
random_forest.fit(X_train, y_train)
pred = random_forest.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.7332459875532263

# %%
test_pred = random_forest.predict(test_dummy)

# %%
test_pred = test_pred.astype('int32')

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_rf.csv',index=False)

# %%
# Optimizing random forest
from sklearn.model_selection import GridSearchCV
parameters = {'n_estimators':range(1,200,20),'criterion':('gini','entropy'),'max_depth':range(2,11)}
gs = GridSearchCV(random_forest, parameters,)

# %%
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ('gini', 'entropy'),
#                          'max_depth': range(2, 11),
#                          'n_estimators': range(1, 200, 20)})

# %%
gs.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 2, 'n_estimators': 1}

# %%
gs.best_score_
# Out:
# 0.7597214833317476
