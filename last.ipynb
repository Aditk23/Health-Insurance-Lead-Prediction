# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings

warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train_copy = train.copy()
test_copy = test.copy()

# %%
train
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 50877  50878        C4          845            Rented          Individual
# 50878  50879        C5         4188            Rented          Individual
# 50879  50880        C1          442            Rented          Individual
# 50880  50881        C1            4             Owned               Joint
# 50881  50882        C3         3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
c1 = train[train['Response']==1].City_Code.value_counts()

c2 = train.City_Code.value_counts()

# %%
train_copy.City_Code  = train_copy.City_Code.replace(c1/c2)

test_copy.City_Code  = test_copy.City_Code.replace(c1/c2)

# %%
train_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1   0.237472         3213            Rented          Individual
# 1          2   0.230205         1117             Owned               Joint
# 2          3   0.230205         3732             Owned          Individual
# 3          4   0.235081         4378             Owned               Joint
# 4          5   0.241971         2190            Rented          Individual
# ...      ...        ...          ...               ...                 ...
# 50877  50878   0.242168          845            Rented          Individual
# 50878  50879   0.230205         4188            Rented          Individual
# 50879  50880   0.246072          442            Rented          Individual
# 50880  50881   0.246072            4             Owned               Joint
# 50881  50882   0.237472         3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
r1 = train[train['Response']==1].Region_Code.value_counts()

r2 = train.Region_Code.value_counts()

# %%
train_copy.Region_Code  = train_copy.Region_Code.replace(r1/r2)

test_copy.Region_Code  = test_copy.Region_Code.replace(r1/r2)

# %%
test_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0      50883   0.246072     0.379310             Owned          Individual
# 1      50884   0.242168     0.218750             Owned               Joint
# 2      50885   0.246072     0.105263            Rented          Individual
# 3      50886   0.237472     0.235294            Rented          Individual
# 4      50887   0.246072     0.384615             Owned          Individual
# ...      ...        ...          ...               ...                 ...
# 21800  72683   0.237472     0.266667             Owned          Individual
# 21801  72684   0.242168     0.363636             Owned          Individual
# 21802  72685   0.228111     0.200000             Owned          Individual
# 21803  72686   0.225947     0.333333            Rented          Individual
# 21804  72687   0.244353     0.200000             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
train_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1   0.237472     0.125000            Rented          Individual
# 1          2   0.230205     0.294118             Owned               Joint
# 2          3   0.230205     0.142857             Owned          Individual
# 3          4   0.235081     0.400000             Owned               Joint
# 4          5   0.241971     0.090909            Rented          Individual
# ...      ...        ...          ...               ...                 ...
# 50877  50878   0.242168     0.166667            Rented          Individual
# 50878  50879   0.230205     0.166667            Rented          Individual
# 50879  50880   0.246072     0.250000            Rented          Individual
# 50880  50881   0.246072     0.191781             Owned               Joint
# 50881  50882   0.237472          NaN            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
sns.distplot(train_copy.Region_Code)
# Out:
# <AxesSubplot:xlabel='Region_Code', ylabel='Density'>

# %%
train_copy.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                 3865
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator           11691
# Holding_Policy_Duration    20251
# Holding_Policy_Type        20251
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                       0
# dtype: int64

# %%
r1.shape
# Out:
# (4048,)

# %%
r2.shape
# Out:
# (5316,)

# %%
train_copy.Region_Code = train_copy.Region_Code.fillna(0)

test_copy.Region_Code = test_copy.Region_Code.fillna(0)

# %%
train_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1   0.237472     0.125000            Rented          Individual
# 1          2   0.230205     0.294118             Owned               Joint
# 2          3   0.230205     0.142857             Owned          Individual
# 3          4   0.235081     0.400000             Owned               Joint
# 4          5   0.241971     0.090909            Rented          Individual
# ...      ...        ...          ...               ...                 ...
# 50877  50878   0.242168     0.166667            Rented          Individual
# 50878  50879   0.230205     0.166667            Rented          Individual
# 50879  50880   0.246072     0.250000            Rented          Individual
# 50880  50881   0.246072     0.191781             Owned               Joint
# 50881  50882   0.237472     0.000000            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
train_copy['Health Indicator'] = train_copy['Health Indicator'].fillna('X10')

test_copy['Health Indicator'] = test_copy['Health Indicator'].fillna('X10')

# %%
test_copy.isnull().sum()
# Out:
# ID                            0
# City_Code                     0
# Region_Code                   0
# Accomodation_Type             0
# Reco_Insurance_Type           0
# Upper_Age                     0
# Lower_Age                     0
# Is_Spouse                     0
# Health Indicator              0
# Holding_Policy_Duration    8603
# Holding_Policy_Type        8603
# Reco_Policy_Cat               0
# Reco_Policy_Premium           0
# dtype: int64

# %%
train_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1   0.237472     0.125000            Rented          Individual
# 1          2   0.230205     0.294118             Owned               Joint
# 2          3   0.230205     0.142857             Owned          Individual
# 3          4   0.235081     0.400000             Owned               Joint
# 4          5   0.241971     0.090909            Rented          Individual
# ...      ...        ...          ...               ...                 ...
# 50877  50878   0.242168     0.166667            Rented          Individual
# 50878  50879   0.230205     0.166667            Rented          Individual
# 50879  50880   0.246072     0.250000            Rented          Individual
# 50880  50881   0.246072     0.191781             Owned               Joint
# 50881  50882   0.237472     0.000000            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
train_copy['Holding_Policy_Duration'] = train_copy['Holding_Policy_Duration'].replace({np.NaN:0})
train_copy['Holding_Policy_Duration'] = train_copy['Holding_Policy_Duration'].replace({'14+':15})
train_copy['Holding_Policy_Duration'] = train_copy['Holding_Policy_Duration'].astype('float32').astype('int32')

test_copy['Holding_Policy_Duration'] = test_copy['Holding_Policy_Duration'].replace({np.NaN:0})
test_copy['Holding_Policy_Duration'] = test_copy['Holding_Policy_Duration'].replace({'14+':15})
test_copy['Holding_Policy_Duration'] = test_copy['Holding_Policy_Duration'].astype('float32').astype('int32')

# %%
test_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0      50883   0.246072     0.379310             Owned          Individual
# 1      50884   0.242168     0.218750             Owned               Joint
# 2      50885   0.246072     0.105263            Rented          Individual
# 3      50886   0.237472     0.235294            Rented          Individual
# 4      50887   0.246072     0.384615             Owned          Individual
# ...      ...        ...          ...               ...                 ...
# 21800  72683   0.237472     0.266667             Owned          Individual
# 21801  72684   0.242168     0.363636             Owned          Individual
# 21802  72685   0.228111     0.200000             Owned          Individual
# 21803  72686   0.225947     0.333333            Rented          Individual
# 21804  72687   0.244353     0.200000             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
train_copy.Holding_Policy_Type = train_copy.Holding_Policy_Type.fillna(5.0)
test_copy.Holding_Policy_Type = test_copy.Holding_Policy_Type.fillna(5.0)

# %%
p1 = train[train['Response']==1].Reco_Policy_Cat.value_counts()

p2 = train.Reco_Policy_Cat.value_counts()

# %%
train_copy.Reco_Policy_Cat  = train_copy.Reco_Policy_Cat.replace(p1/p2)

test_copy.Reco_Policy_Cat  = test_copy.Reco_Policy_Cat.replace(p1/p2)

# %%
train_copy.isnull().sum()
# Out:
# ID                         0
# City_Code                  0
# Region_Code                0
# Accomodation_Type          0
# Reco_Insurance_Type        0
# Upper_Age                  0
# Lower_Age                  0
# Is_Spouse                  0
# Health Indicator           0
# Holding_Policy_Duration    0
# Holding_Policy_Type        0
# Reco_Policy_Cat            0
# Reco_Policy_Premium        0
# Response                   0
# dtype: int64

# %%
test_copy.isnull().sum()
# Out:
# ID                         0
# City_Code                  0
# Region_Code                0
# Accomodation_Type          0
# Reco_Insurance_Type        0
# Upper_Age                  0
# Lower_Age                  0
# Is_Spouse                  0
# Health Indicator           0
# Holding_Policy_Duration    0
# Holding_Policy_Type        0
# Reco_Policy_Cat            0
# Reco_Policy_Premium        0
# dtype: int64

# %%
train_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1   0.237472     0.125000            Rented          Individual
# 1          2   0.230205     0.294118             Owned               Joint
# 2          3   0.230205     0.142857             Owned          Individual
# 3          4   0.235081     0.400000             Owned               Joint
# 4          5   0.241971     0.090909            Rented          Individual
# ...      ...        ...          ...               ...                 ...
# 50877  50878   0.242168     0.166667            Rented          Individual
# 50878  50879   0.230205     0.166667            Rented          Individual
# 50879  50880   0.246072     0.250000            Rented          Individual
# 50880  50881   0.246072     0.191781             Owned               Joint
# 50881  50882   0.237472     0.000000            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
test_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0      50883   0.246072     0.379310             Owned          Individual
# 1      50884   0.242168     0.218750             Owned               Joint
# 2      50885   0.246072     0.105263            Rented          Individual
# 3      50886   0.237472     0.235294            Rented          Individual
# 4      50887   0.246072     0.384615             Owned          Individual
# ...      ...        ...          ...               ...                 ...
# 21800  72683   0.237472     0.266667             Owned          Individual
# 21801  72684   0.242168     0.363636             Owned          Individual
# 21802  72685   0.228111     0.200000             Owned          Individual
# 21803  72686   0.225947     0.333333            Rented          Individual
# 21804  72687   0.244353     0.200000             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
sns.distplot(train_copy.Reco_Policy_Premium)
# Out:
# <AxesSubplot:xlabel='Reco_Policy_Premium', ylabel='Density'>

# %%
sns.distplot(test_copy.Reco_Policy_Premium)
# Out:
# <AxesSubplot:xlabel='Reco_Policy_Premium', ylabel='Density'>

# %%
train_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1   0.237472     0.125000            Rented          Individual
# 1          2   0.230205     0.294118             Owned               Joint
# 2          3   0.230205     0.142857             Owned          Individual
# 3          4   0.235081     0.400000             Owned               Joint
# 4          5   0.241971     0.090909            Rented          Individual
# ...      ...        ...          ...               ...                 ...
# 50877  50878   0.242168     0.166667            Rented          Individual
# 50878  50879   0.230205     0.166667            Rented          Individual
# 50879  50880   0.246072     0.250000            Rented          Individual
# 50880  50881   0.246072     0.191781             Owned               Joint
# 50881  50882   0.237472     0.000000            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
X = train_copy.drop(['ID','Lower_Age','Is_Spouse','Response'],1)
testing = test_copy.drop(['ID','Lower_Age','Is_Spouse'],1)

# %%
y = train_copy.Response

# %%
X = pd.get_dummies(X,columns=['Accomodation_Type','Reco_Insurance_Type', 'Health Indicator',
                     'Holding_Policy_Type'])
testing = pd.get_dummies(testing,columns=['Accomodation_Type','Reco_Insurance_Type', 'Health Indicator',
                     'Holding_Policy_Type'])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled= sc.fit_transform(X)
testing_scaled = sc.fit_transform(testing)

# %%
X
# Out:
#        City_Code  Region_Code  Upper_Age  Holding_Policy_Duration  \
# 0       0.237472     0.125000         36                       15
# 1       0.230205     0.294118         75                        0
# 2       0.230205     0.142857         32                        1
# 3       0.235081     0.400000         52                       15
# 4       0.241971     0.090909         44                        3
# ...          ...          ...        ...                      ...
# 50877   0.242168     0.166667         22                        0
# 50878   0.230205     0.166667         27                        7
# 50879   0.246072     0.250000         63                       15
# 50880   0.246072     0.191781         71                        2
# 50881   0.237472     0.000000         24                        2
#
#        Reco_Policy_Cat  Reco_Policy_Premium  Accomodation_Type_Owned  \
# 0             0.328385              11628.0                        0
# ...

# %%
X.columns
# Out:
# Index(['City_Code', 'Region_Code', 'Upper_Age', 'Holding_Policy_Duration',
#        'Reco_Policy_Cat', 'Reco_Policy_Premium', 'Accomodation_Type_Owned',
#        'Accomodation_Type_Rented', 'Reco_Insurance_Type_Individual',
#        'Reco_Insurance_Type_Joint', 'Health Indicator_X1',
#        'Health Indicator_X10', 'Health Indicator_X2', 'Health Indicator_X3',
#        'Health Indicator_X4', 'Health Indicator_X5', 'Health Indicator_X6',
#        'Health Indicator_X7', 'Health Indicator_X8', 'Health Indicator_X9',
#        'Holding_Policy_Type_1.0', 'Holding_Policy_Type_2.0',
#        'Holding_Policy_Type_3.0', 'Holding_Policy_Type_4.0',
#        'Holding_Policy_Type_5.0'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)


from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score
random_forest1 = RandomForestRegressor()
                                       
random_forest1.fit(X_train, y_train) 
pred = random_forest1.predict(X_test)
roc_auc_score(y_test, pred, average=None)
# Out:
# 0.7311552631756046

# %%
sns.distplot(pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
test_pred = pred = random_forest1.predict(testing)

# %%
sns.distplot(test_pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_random_forest.csv',index=False)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3)


from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score
random_forest2 = RandomForestRegressor()
                                       
random_forest2.fit(X_train, y_train) 
pred = random_forest2.predict(X_test)
roc_auc_score(y_test, pred, average=None)
# Out:
# 0.7343024728670388

# %%
test_pred = pred = random_forest2.predict(testing)

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_random_forest2.csv',index=False)

# %%
sns.distplot(test_pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(random_state=0)
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
pred = decision_tree.predict(X_test)
roc_auc_score(y_test, pred, average=None)
# Out:
# 0.5832016010538583

# %%
test_pred=decision_tree.predict(testing_scaled)

# %%
test_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
sns.distplot(test_pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_decision_tree.csv',index=False)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression().fit(X_train, y_train)
pred = lr.predict(X_test)
roc_auc_score(y_test, pred, average=None)
# Out:
# 0.5666236003445306

# %%
sns.distplot(pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
X
# Out:
#        City_Code  Region_Code  Upper_Age  Holding_Policy_Duration  \
# 0       0.237472     0.125000         36                       15
# 1       0.230205     0.294118         75                        0
# 2       0.230205     0.142857         32                        1
# 3       0.235081     0.400000         52                       15
# 4       0.241971     0.090909         44                        3
# ...          ...          ...        ...                      ...
# 50877   0.242168     0.166667         22                        0
# 50878   0.230205     0.166667         27                        7
# 50879   0.246072     0.250000         63                       15
# 50880   0.246072     0.191781         71                        2
# 50881   0.237472     0.000000         24                        2
#
#        Reco_Policy_Cat  Reco_Policy_Premium  Accomodation_Type_Owned  \
# 0             0.328385              11628.0                        0
# ...

# %%
test_pred = lr.predict_proba(X_test)[:,1]

# %%
sns.distplot(pd.DataFrame(a))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
decision_tree.predict_proba(X_test)[:,1]
# Out:
# array([1., 1., 0., ..., 0., 0., 0.])

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()
                                       
random_forest.fit(X_train, y_train) 
pred = random_forest.predict_proba(X_test)[:,1]
sns.distplot(pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
roc_auc_score(y_test, pred, average=None)
# Out:
# 0.730679693787256

# %%
test_pred = random_forest.predict_proba(testing_scaled)[:,1]

# %%
sns.distplot(test_pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_rf_probab.csv',index=False)

# %%
train_copy
# Out:
#           ID  City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1   0.237472     0.125000            Rented          Individual
# 1          2   0.230205     0.294118             Owned               Joint
# 2          3   0.230205     0.142857             Owned          Individual
# 3          4   0.235081     0.400000             Owned               Joint
# 4          5   0.241971     0.090909            Rented          Individual
# ...      ...        ...          ...               ...                 ...
# 50877  50878   0.242168     0.166667            Rented          Individual
# 50878  50879   0.230205     0.166667            Rented          Individual
# 50879  50880   0.246072     0.250000            Rented          Individual
# 50880  50881   0.246072     0.191781             Owned               Joint
# 50881  50882   0.237472     0.000000            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# ...

# %%
train_copy.Accomodation_Type = train_copy.Accomodation_Type.map({'Rented':0,'Owned':1})
test_copy.Accomodation_Type = test_copy.Accomodation_Type.map({'Rented':0,'Owned':1})

# %%
train_copy.Reco_Insurance_Type = train_copy.Reco_Insurance_Type.map({'Individual':0,'Joint':1})
test_copy.Reco_Insurance_Type = test_copy.Reco_Insurance_Type.map({'Individual':0,'Joint':1})

# %%
sns.distplot(train_copy.Upper_Age)
# Out:
# <AxesSubplot:xlabel='Upper_Age', ylabel='Density'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3)

import lightgbm as lgb
clf = lgb.LGBMClassifier()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
roc_auc_score(y_test, pred, average=None)
# Out:
# 0.5684304386375837

# %%
test_pred = clf.predict_proba(testing_scaled)[:,1]

# %%
sns.distplot(test_pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_lgbm.csv',index=False)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3)

from xgboost import XGBClassifier
clf = XGBClassifier()
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
roc_auc_score(y_test, pred, average=None)
# Out:
# 0.5774539877300614

# %%
test_pred = clf.predict_proba(testing_scaled)[:,1]

# %%
sns.distplot(test_pred)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sub = pd.read_csv('sample_submission.csv')

sub['ID'] = test.ID
sub['Response'] = test_pred

sub.to_csv('predictions_xgb.csv',index=False)

# %%
X
# Out:
#        City_Code  Region_Code  Upper_Age  Holding_Policy_Duration  \
# 0       0.237472     0.125000         36                       15
# 1       0.230205     0.294118         75                        0
# 2       0.230205     0.142857         32                        1
# 3       0.235081     0.400000         52                       15
# 4       0.241971     0.090909         44                        3
# ...          ...          ...        ...                      ...
# 50877   0.242168     0.166667         22                        0
# 50878   0.230205     0.166667         27                        7
# 50879   0.246072     0.250000         63                       15
# 50880   0.246072     0.191781         71                        2
# 50881   0.237472     0.000000         24                        2
#
#        Reco_Policy_Cat  Reco_Policy_Premium  Accomodation_Type_Owned  \
# 0             0.328385              11628.0                        0
# ...
